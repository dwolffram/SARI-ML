# %%
import sys
sys.path.append('../')
from src.load_data import *
from src.plot_functions import *
from src.realtime_utils import *

# %% [markdown]
# # Latest data (no maximum delay)

# %%
ts = load_data(SOURCES)

# %%
ts['icosari-sari-DE'].plot()
ts['survstat-influenza-DE'].plot()
ts['agi-are-DE'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # Target data (4 weeks maximum delay)

# %%
ts_target = load_target_series()

# %%
ts_target.plot()
# Out:
# <Axes: xlabel='date'>
