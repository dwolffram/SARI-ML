# %% [markdown]
# # hhh4: Forecasts

# %% [markdown]
# ### Setup

# %%
import sys
sys.path.append('../')
from src.load_data import *
from src.realtime_utils import *
from src.plot_functions import *

# %% [markdown]
# # Plots

# %%
target_sari = load_target_series('sari')

# %%
h = pd.concat([pd.read_csv(file, parse_dates=['forecast_date', 'target_end_date']) for file in glob.glob('../data/post-covid/submissions/KIT-hhh4/*.csv')])

# %%
h = h[h.type == 'quantile']

# %%
df_plot = prepare_plot_data(h, target_sari)

# %%
plot_forecasts(df_plot, 'national', start=0)

# %%
plot_forecasts(df_plot, 'age', start=0)

# %%
plot_forecasts(df_plot, 'age', horizon=1)

# %%
plot_forecasts(df_plot, 'national', horizon=1)
