# %% [markdown]
# # Training data (to mimic realtime setting)

# %% [markdown]
# ### Setup

# %%
import sys
sys.path.append('../')
from src.load_data import *
from src.realtime_utils import *
from src.hp_tuning_functions import *

# %% [markdown]
# # Load data

# %%
covariates, targets = load_realtime_training_data('2024-10-24')

# %%
targets.start_time(), targets.end_time()
# Out:
# (Timestamp('2012-10-07 00:00:00'), Timestamp('2024-09-22 00:00:00'))

# %%
covariates.start_time(), covariates.end_time()
# Out:
# (Timestamp('2014-10-05 00:00:00'), Timestamp('2024-09-22 00:00:00'))

# %%
targets.plot()
# Out:
# <Axes: xlabel='date'>

# %%
covariates.plot()
# Out:
# <Axes: xlabel='date'>
